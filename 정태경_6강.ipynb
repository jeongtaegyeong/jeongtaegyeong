# %% [markdown]
# <a href="https://colab.research.google.com/github/jeongtaegyeong/jeongtaegyeong/blob/main/%EC%A0%95%ED%83%9C%EA%B2%BD_6%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###8주차

# %%
import matplotlib.pyplot as plt

# %%
data = {'age': [23,43,12,45], 'name':['민준','현우','서연','동현'], 'height': [175.3 , 180.3 , 165.8, 172.7]}
x = pd.DataFrame(data, columns = ['name', 'age', 'height'])
x
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7

# %%
x.loc[4]=['광현',32,176] ### 행 추가
x
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0

# %%
y= pd.DataFrame({'age':[33],'name':['철수'],'height':180.}, columns=['age','name','height'])
y
# Out:
#    age name  height
# 0   33   철수   180.0

# %%
result = x.append(y)

# %%
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 0   철수   33   180.0

# %%
result=x.append(y,ignore_index=True)
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 5   철수   33   180.0

# %%
x=x.append(y,ignore_index=True)
x
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 5   철수   33   180.0

# %%
result = pd.concat([x,y], ignore_index=True)

# %%
result
# Out:
#   name  age  height
# 0   민준   23   175.3
# 1   현우   43   180.3
# 2   서연   12   165.8
# 3   동현   45   172.7
# 4   광현   32   176.0
# 5   철수   33   180.0
# 6   철수   33   180.0

# %%
### NaN은 데이터들에서 예상치 못한 값을 의미
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0 -1.106621  0.144652  2.441734 -2.041382 -1.145054
# 1  0.320059       NaN -0.460950 -1.762861 -0.949641
# 2  0.066586  1.186691       NaN -0.452417 -1.846407
# 3 -0.124442  0.463610  0.745596  0.285733 -0.444643
# 4 -1.050594  1.194961  1.185652 -0.281066 -0.607555

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B        C         D         E
# 1  0.320059 NaN -0.46095 -1.762861 -0.949641

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  1.059938  0.284764  0.325942  1.479348 -0.714780
# 1 -0.202271       NaN  1.956347  0.574416  0.064621
# 2 -0.070519  0.900282       NaN  0.190463  1.188590
# 3 -0.440421  1.355987  0.022938  1.504323  0.354240
# 4  0.736249  0.565231 -0.798934  0.969279 -0.265693

# %%
df.dropna() ### NaN이 있는 행을 삭제하는 명령
# Out:
#           A         B         C         D         E
# 0  1.059938  0.284764  0.325942  1.479348 -0.714780
# 3 -0.440421  1.355987  0.022938  1.504323  0.354240
# 4  0.736249  0.565231 -0.798934  0.969279 -0.265693

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0 -0.693623  0.455318 -0.072902  0.922111  0.747326
# 1  0.042710       NaN  0.796082  0.062493 -0.587239
# 2  0.385220  0.609814       NaN -0.348633 -0.380060
# 3 -1.495933  1.406356 -0.526256  0.649691 -1.252066
# 4  0.584379 -0.417742  2.567210  0.495540 -0.808199

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -0.693623  0.455318 -0.072902  0.922111  0.747326
# 3 -1.495933  1.406356 -0.526256  0.649691 -1.252066
# 4  0.584379 -0.417742  2.567210  0.495540 -0.808199

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0 -0.055201  1.476506  1.658595  0.089487 -1.211853
# 1  1.220054       NaN -0.439652 -0.964393  0.852273
# 2  0.949278  0.128057       NaN  0.533549 -0.598045
# 3  1.863513 -0.062700 -1.283669  1.621173 -1.605764
# 4 -0.593758 -0.846011 -0.510086 -0.278891 -1.676446

# %%
df.dropna(subset=['B'],axis=0, inplace=True) ### axis=0 은 행을 삭제한다는 뜻
df
# Out:
#           A         B         C         D         E
# 0 -0.055201  1.476506  1.658595  0.089487 -1.211853
# 2  0.949278  0.128057       NaN  0.533549 -0.598045
# 3  1.863513 -0.062700 -1.283669  1.621173 -1.605764
# 4 -0.593758 -0.846011 -0.510086 -0.278891 -1.676446

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  0.473330 -0.594802  0.533247 -1.349552  0.194203
# 1  0.195640       NaN  1.553359  0.151189  0.067588
# 2  0.559286 -0.555575       NaN -0.292919 -1.991133
# 3 -1.033960  0.647856  1.691212  1.284444  0.422197
# 4  1.537741 -0.397213 -1.985655 -0.479031 -0.151325

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#           A         D         E
# 0  0.473330 -1.349552  0.194203
# 1  0.195640  0.151189  0.067588
# 2  0.559286 -0.292919 -1.991133
# 3 -1.033960  1.284444  0.422197
# 4  1.537741 -0.479031 -0.151325

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0  2.037818  1.165164  1.083816  0.537965  0.203131
# 1 -1.562352       NaN  0.433501  1.941273 -0.292947
# 2 -1.008048  3.185214       NaN  1.657198  0.138156
# 3  1.535126  1.020405  0.511899  0.704138  1.656079
# 4 -1.351538  0.270981  0.382178  0.916464  0.278941

# %%
df.dropna(subset=[0,1], axis=1,inplace=True)
df
# Out:
#           A         C         D         E
# 0  2.037818  1.083816  0.537965  0.203131
# 1 -1.562352  0.433501  1.941273 -0.292947
# 2 -1.008048       NaN  1.657198  0.138156
# 3  1.535126  0.511899  0.704138  1.656079
# 4 -1.351538  0.382178  0.916464  0.278941

# %%
robots = [[24,23680],[35,np.nan],[46,47350],[27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
data.replace(np.nan,0,inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean, inplace=True)
data   ### inplace=True를 하지 않으면 data가 바뀌지 않는다
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
mean=data['price'].mean()
data.replace(np.nan,mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      0.0
# 2         46  47350.0
# 3         27      0.0

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris") ### 붓꽃 데이터

# %%
iris.head() ### 왼쪽부터 꽃받침길이,꽃받침너비,꽃잎길이,꽃잎너비,종
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
### kedplot(), 1차원 array의 분포를 나타내는 그래프 + 부드러운 곡선
vals = iris['sepal_length'].values
sns.kdeplot(vals)
plt.title("kdepolot for sepal length")
plt.show()

# %%
vals = iris['petal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for petal length")
plt.show()

# %%
vals = iris['petal_length'].values ### 이상하게 나오는데...?
sns.displot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()
### displot(), ked plot과 rug plot을 true로 설정하면 kernel density graph,rug가 나옴

# %%
sns.displot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()

# %%
titanic = sns.load_dataset("titanic") # 타이타닉호 데이터
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male",data=titanic)
plt.show()

# %%
titanic.adult_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: adult_male, Length: 891, dtype: bool

# %%
tips = sns.load_dataset("tips") # 팁데이터
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='scatter')
plt.show()

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris, hue='species', kind='kde')
plt.show()

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
plt.show()

# %%
titanic_size = titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()

# %%
sns.heatmap(titanic_size, annot=True, fmt='d')
plt.title("Heatmap")
plt.show() ### 옵션에서 annot=True을 하면 숫자가 박스위에 나오고 fmt=d를 하면 정수형으로 수를 볼수 있음

# %%
sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu"),annot=True, fmt='d')
plt.title("Heatmap")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title('Tips on each day')
plt.show()### 카테고리 값에 따른 실수 값의 평균,편차를 표시, 바의 높이가 평균, 검정색 선이 편차

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.title('Tips on each day')
plt.show() ### jitter=True 는 데이터 수가 많은 경우 점의 가로축 상의 위치를 무작위로 바꿔줌

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)
plt.title('Tips on each day')
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.title('Tips on each day')
plt.show() ### 점이 많을 경우 점들이 겹치치 않게 좌우로 퍼지도록 한다

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title('Tips on each day')
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", hue='sex', data=tips, split=True)
plt.title('Tips on each day with hue=sex and split=True')
plt.show()

# %%
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips, dodge=True)
plt.title('Tips on each day with hue=sex and dodge=True')
plt.show()

# %%
sns.catplot(x="age", y="sex",hue="survived", row="class",data=titanic,kind="violin",split="True", height=2, aspect=4)
plt.title("Catplot of titanic with hue=survived")
plt.show()

# %%
plt.title("violinplt and swarmplot")
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='0.9')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-3beaa07ed608> in <module>
#       1 plt.title("violinplt and swarmplot")
# ----> 2 sns.violinplot(x='day', y='total_bill', data=tips)
#       3 sns.swarmplot(x='day', y='total_bill', data=tips, color='0.9')
#       4 plt.show()
#
# NameError: name 'tips' is not defined

# %%
### 9주차

# %%
df_train = pd.read_csv('/content/train.csv')
df_test = pd.read_csv('/content/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train['Age'].isnull().sum()
# Out:
# 177

# %%
100*df_train['Age'].isnull().sum()/df_train[df_train.columns].shape[0]
# Out:
# 19.865319865319865

# %%
for col in df_train.columns:
  msg = '{:>10} : \t Percentage of NaN: {:.2f}%'. format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
print(msg)
# Out:
#   Embarked : 	 Percentage of NaN: 0.22%

# %%
import missingno as msno

# %%
msno.matrix(df=df_train, figsize=(6,6))
plt.show()

# %%
msno.bar(df=df_train, figsize=(6,6))
plt.show()

# %%
df_train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_train['Survived'].value_counts().plot.bar()

# %%
df_train['Survived'].value_counts().plot.pie()
plt.show()

# %%
df_train['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct = '%1.1f%%')
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x='Survived', data=df_train)
plt.show()

# %%
df_train[['Pclass', 'Survived']]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
### 타입 개체는 첨자할수 없다...?
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-185-ee4c31937b43> in <module>
# ----> 1 df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_vaules'

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-7e98fdf6853d> in <module>
# ----> 1 df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_vaules'

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_93998_row0_col0, #T_93998_row1_col1, #T_93998_row1_col2 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_93998_row0_col1 {
#   background-color: #31ceff;
#   color: #000000;
# }
# #T_93998_row0_col2 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_93998_row1_col0 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_93998_row2_col0 {
#   background-color: #9f60ff;
#   color: #f1f1f1;
# }
# #T_93998_row2_col1 {
#   background-color: #20dfff;
#   color: #000000;
# }
# #T_93998_row2_col2 {
#   background-color: #6f90ff;
#   color: #f1f1f1;
# }
# #T_93998_row3_col0, #T_93998_row3_col1, #T_93998_row3_col2 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93998_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93998_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_93998_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_93998_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_93998_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_93998_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_93998_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_93998_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_93998_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_93998_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_93998_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_93998_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_93998_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_93998_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_93998_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_93998_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_93998_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-7e98fdf6853d> in <module>
# ----> 1 df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_vaules'

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False').plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-e662b9e28d72> in <module>
# ----> 1 df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False').plot()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_vaules'

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False').plot.bar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-178-4fe0636b15aa> in <module>
# ----> 1 df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_vaules(by='Survived, ascending=False').plot.bar()
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_vaules'

# %%
df_train['Pclass'].value_counts().plot.bar()
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=df_train)
plt.show()

# %%
sns.set(font_scale=2.5)

# %%
f, ax = plt.subplots(1,2,figsize=(16,8))
df_train['Pclass'].value_counts().plot.bar(ax=ax[0])
sns.countplot(x='Pclass', hue='Survived', data=df_train, ax=ax[1])
plt.show()
